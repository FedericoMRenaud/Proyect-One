# %%
import pandas as pd
import os

CO2_emissions_data= os.path.join("Resources/API_EN.ATM.CO2E.KT_DS2_en_csv_v2_713263.csv")
CO2_emissions_df=pd.read_csv(CO2_emissions_data, skiprows=4)
CO2_emissions_df.head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 2       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 3      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
# 4      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
#
#        1961      1962      1963      1964      1965  ...       2011  \
# 0       NaN       NaN       NaN       NaN       NaN  ...   2500.894
# 1   491.378   689.396   707.731   839.743  1008.425  ...  12240.446
# 2   454.708  1180.774  1151.438  1224.778  1188.108  ...  30340.758
# 3  2280.874  2464.224  2082.856  2016.850  2174.531  ...   5240.143
# 4       NaN       NaN       NaN       NaN       NaN  ...    491.378
#
#         2012       2013       2014  2015  2016  2017  2018  2019  Unnamed: 64
# 0   1349.456    861.745    872.746   NaN   NaN   NaN   NaN   NaN          NaN
# 1  10755.311  10014.577   9809.225   NaN   NaN   NaN   NaN   NaN          NaN
# 2  33399.036  32617.965  34763.160   NaN   NaN   NaN   NaN   NaN          NaN
# 3   4910.113   5064.127   5716.853   NaN   NaN   NaN   NaN   NaN          NaN
# 4    487.711    476.710    462.042   NaN   NaN   NaN   NaN   NaN          NaN
#
# [5 rows x 65 columns]

# %%
import pandas as pd
import os

pop_grow_data= os.path.join("API_SP.POP.GROW_DS2_en_csv_v2_715046.csv")
pop_grow_df=pd.read_csv(pop_grow_data, skiprows=4)
pop_grow_df.head()
# Out:
#   Country Name Country Code                Indicator Name Indicator Code  \
# 0        Aruba          ABW  Population growth (annual %)    SP.POP.GROW
# 1  Afghanistan          AFG  Population growth (annual %)    SP.POP.GROW
# 2       Angola          AGO  Population growth (annual %)    SP.POP.GROW
# 3      Albania          ALB  Population growth (annual %)    SP.POP.GROW
# 4      Andorra          AND  Population growth (annual %)    SP.POP.GROW
#
#        1960      1961      1962      1963      1964      1965  ...      2011  \
# 0  3.148037  2.238144  1.409622  0.832453  0.592649  0.573468  ...  0.370125
# 1  1.828639  1.898476  1.965751  2.029893  2.090248  2.147567  ...  3.143126
# 2  1.369926  1.393363  1.383629  1.256555  0.973962  0.617544  ...  3.634159
# 3  3.015423  3.120855  3.056731  2.953749  2.880686  2.754021  ... -0.269017
# 4  7.050663  6.941532  6.692697  6.559522  6.241511  5.998800  ... -0.834745
#
# ...

# %%
import pandas as pd
import os

refugee_country_origin_data= os.path.join("API_SM.POP.REFG.OR_DS2_en_csv_v2_718614.csv")
refugee_country_origin_df=pd.read_csv(refugee_country_origin_data, skiprows=4)
refugee_country_origin_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Refugee population by country or territory of ...  SM.POP.REFG.OR   NaN
# 1  Refugee population by country or territory of ...  SM.POP.REFG.OR   NaN
# 2  Refugee population by country or territory of ...  SM.POP.REFG.OR   NaN
# 3  Refugee population by country or territory of ...  SM.POP.REFG.OR   NaN
# 4  Refugee population by country or territory of ...  SM.POP.REFG.OR   NaN
#
#    1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  2664436.0  2586152.0  2556502.0
# 2   NaN   NaN   NaN   NaN   NaN  ...   128664.0    19258.0    10286.0
# ...

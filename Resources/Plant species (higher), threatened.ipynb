# %%
import pandas as pd
import os

plant_threaten_data= os.path.join("Resources/API_EN.HPT.THRD.NO_DS2_en_csv_v2_716046.csv")
plant_threaten_df=pd.read_csv(plant_threaten_data, skiprows=4)
plant_threaten_df.head()
# Out:
#   Country Name Country Code                      Indicator Name  \
# 0        Aruba          ABW  Plant species (higher), threatened
# 1  Afghanistan          AFG  Plant species (higher), threatened
# 2       Angola          AGO  Plant species (higher), threatened
# 3      Albania          ALB  Plant species (higher), threatened
# 4      Andorra          AND  Plant species (higher), threatened
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...  2011  2012  2013  \
# 0  EN.HPT.THRD.NO   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 1  EN.HPT.THRD.NO   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 2  EN.HPT.THRD.NO   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 3  EN.HPT.THRD.NO   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 4  EN.HPT.THRD.NO   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
#
#    2014  2015  2016  2017  2018  2019  Unnamed: 64
# 0   NaN   NaN   NaN   NaN   2.0   NaN          NaN
# ...

# %%
import pandas as pd
import os

droughts_floods_exttemp_data= os.path.join("Resources/API_EN.CLC.MDAT.ZS_DS2_en_csv_v2_713688.csv")
droughts_floods_exttemp_df=pd.read_csv(droughts_floods_exttemp_data, skiprows=4)
droughts_floods_exttemp_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Droughts, floods, extreme temperatures (% of p...  EN.CLC.MDAT.ZS   NaN
# 1  Droughts, floods, extreme temperatures (% of p...  EN.CLC.MDAT.ZS   NaN
# 2  Droughts, floods, extreme temperatures (% of p...  EN.CLC.MDAT.ZS   NaN
# 3  Droughts, floods, extreme temperatures (% of p...  EN.CLC.MDAT.ZS   NaN
# 4  Droughts, floods, extreme temperatures (% of p...  EN.CLC.MDAT.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2011  2012  2013  2014  2015  2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2017  2018  2019  Unnamed: 64
# 0   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN          NaN
# 3   NaN   NaN   NaN          NaN
# 4   NaN   NaN   NaN          NaN
#
# [5 rows x 65 columns]

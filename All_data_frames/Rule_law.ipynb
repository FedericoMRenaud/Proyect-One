# %%
import pandas as pd
import os

rule_law_data= os.path.join("Resources/rule_law_data.csv")
rule_law_df=pd.read_csv(rule_law_data)
rule_law_df
# Out:
#      Country ISO3 Country Name  Indicator Id              Indicator  \
# 0             ABW        Aruba           364  Control of Corruption
# 1             ABW        Aruba           366  Control of Corruption
# 2             ABW        Aruba           367  Control of Corruption
# 3             ABW        Aruba           368  Control of Corruption
# 4             ABW        Aruba           369  Control of Corruption
# ...           ...          ...           ...                    ...
# 6115          ZWE     Zimbabwe           394     Regulatory Quality
# 6116          ZWE     Zimbabwe           396     Regulatory Quality
# 6117          ZWE     Zimbabwe           397     Regulatory Quality
# 6118          ZWE     Zimbabwe           398     Regulatory Quality
# 6119          ZWE     Zimbabwe           399     Regulatory Quality
#
#      Subindicator Type       1996       1998       2000      2002      2003  \
# ...

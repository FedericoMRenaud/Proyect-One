# %%
import pandas as pd
import os

mammal_threaten_data= os.path.join("Resources/API_EN.MAM.THRD.NO_DS2_en_csv_v2_714728.csv")
mammal_threaten_df=pd.read_csv(mammal_threaten_data, skiprows=4)
mammal_threaten_df.head()
# Out:
#   Country Name Country Code              Indicator Name  Indicator Code  1960  \
# 0        Aruba          ABW  Mammal species, threatened  EN.MAM.THRD.NO   NaN
# 1  Afghanistan          AFG  Mammal species, threatened  EN.MAM.THRD.NO   NaN
# 2       Angola          AGO  Mammal species, threatened  EN.MAM.THRD.NO   NaN
# 3      Albania          ALB  Mammal species, threatened  EN.MAM.THRD.NO   NaN
# 4      Andorra          AND  Mammal species, threatened  EN.MAM.THRD.NO   NaN
#
#    1961  1962  1963  1964  1965  ...  2011  2012  2013  2014  2015  2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2017  2018  2019  Unnamed: 64
# ...

# %%
import pandas as pd
import os

gpd_per_capita_data= os.path.join("Resources/API_NY.GDP.PCAP.KD.ZG_DS2_en_csv_v2_712993.csv")
gpd_per_capita_df=pd.read_csv(gpd_per_capita_data, skiprows=4)
gpd_per_capita_df.head()
# Out:
#   Country Name Country Code                    Indicator Name  \
# 0        Aruba          ABW  GDP per capita growth (annual %)
# 1  Afghanistan          AFG  GDP per capita growth (annual %)
# 2       Angola          AGO  GDP per capita growth (annual %)
# 3      Albania          ALB  GDP per capita growth (annual %)
# 4      Andorra          AND  GDP per capita growth (annual %)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...      2011  \
# 0  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...  3.063882
# 1  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ... -2.681081
# 2  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ... -0.220847
# 3  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.821559
# 4  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ... -3.847253
#
#        2012      2013      2014      2015      2016      2017      2018  2019  \
# 0 -1.864168  3.593198  0.250567 -0.991548 -0.716487  0.855431       NaN   NaN
# 1  8.974880  1.974169 -0.665271 -1.622887 -0.541697  0.082079 -1.350178   NaN
# 2  4.706459  1.292086  1.219833 -2.468715 -5.816237 -3.409903 -5.287780   NaN
# 3  1.585155  1.187205  1.985426  2.516852  3.480117  3.916612  4.402515   NaN
# 4 -0.039668  2.405292  4.293204  2.395989  2.830284  2.115060  1.622747   NaN
#
#    Unnamed: 64
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 65 columns]
